# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
frame = np.load("./records/frame.npy")
reward = np.load("./records/reward.npy")
l_p_f = np.load("./records/loss_policy_fire.npy")
l_p_a = np.load("./records/loss_policy_aim.npy")
l_v = np.load("./records/loss_value.npy")

# %%
plt.plot(frame,l_p_f)

# %%
plt.plot(frame,l_p_a)

# %%
plt.plot(frame,l_v)

# %%
plt.plot(range(reward.shape[0]), reward)
