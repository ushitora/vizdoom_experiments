# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
frame = np.load("./records/frame.npy")
reward = np.load("./records/reward.npy")
l_p = np.load("./records/loss_policy.npy")
l_v = np.load("./records/loss_value.npy")
ent = np.load("./records/entropy.npy")
death = np.load("./records/death.npy")
frag = np.load("./records/frag.npy")

# %%
plt.plot(frame,l_p)

# %%
plt.plot(frame,l_v)

# %%
plt.plot(frame,ent)

# %%
plt.plot(range(reward.shape[0]), reward)

# %%
plt.plot(range(death.shape[0]), death)
